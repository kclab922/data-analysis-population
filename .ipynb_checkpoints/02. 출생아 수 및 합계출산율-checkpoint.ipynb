# %%
import pandas as pd
file_name = '142801_20231129165218317_excel.xlsx'
df = pd.read_excel(file_name, skiprows=2, nrows=2, index_col=0) 
# 맨위 2행 스킵, 컬럼헤드 외에 2행 사용, 인덱스 열에 아무 값 없으므로 인덱스컬럼의 인덱스값인 0만 써줘도 됨
df.head(3)
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
#            2011     2012     2013     2014     2015     2016     2017  \
# 출생아 수   471.300  484.600  436.500  435.400  438.400  406.200  357.800
# 합계 출산율    1.244    1.297    1.187    1.205    1.239    1.172    1.052
#
#            2018     2019     2020
# 출생아 수   326.800  302.700  272.300
# 합계 출산율    0.977    0.918    0.837

# %%
df.index
# Out:
# Index(['출생아 수', '합계 출산율'], dtype='object')

# %%
df.index.values
# Out:
# array(['출생아\xa0수', '합계\xa0출산율'], dtype=object)

# %%
df.rename(index={'출생아\xa0수':'출생아 수', '합계\xa0출산율':'합계 출산율'}, inplace=True)
df.index.values
# Out:
# array(['출생아 수', '합계 출산율'], dtype=object)

# %%
df.loc['출생아 수']
# Out:
# 2011    471.3
# 2012    484.6
# 2013    436.5
# 2014    435.4
# 2015    438.4
# 2016    406.2
# 2017    357.8
# 2018    326.8
# 2019    302.7
# 2020    272.3
# Name: 출생아 수, dtype: float64

# %%
df.iloc[0]
# Out:
# 2011    471.3
# 2012    484.6
# 2013    436.5
# 2014    435.4
# 2015    438.4
# 2016    406.2
# 2017    357.8
# 2018    326.8
# 2019    302.7
# 2020    272.3
# Name: 출생아 수, dtype: float64

# %%
# 행열 전환
df = df.T
df
# Out:
#       출생아 수  합계 출산율
# 2011  471.3   1.244
# 2012  484.6   1.297
# 2013  436.5   1.187
# 2014  435.4   1.205
# 2015  438.4   1.239
# 2016  406.2   1.172
# 2017  357.8   1.052
# 2018  326.8   0.977
# 2019  302.7   0.918
# 2020  272.3   0.837

# %%
import matplotlib.pyplot as plt
import matplotlib
matplotlib.rcParams['font.family'] = 'Malgun Gothic' # WIndows
# matplotlib.rcParams['font.family'] = 'AppleGothic' # Mac
matplotlib.rcParams['font.size'] = 15 # 글자 크기
matplotlib.rcParams['axes.unicode_minus'] = False # 한글 폰트 사용 시 마이너스 숫자가 깨지는 현상을 해결

# %%
plt.plot(df.index, df['출생아 수'])
plt.plot(df.index, df['합계 출산율'])
plt.show()

# %%
fig, ax1 = plt.subplots(figsize=(7, 5))
ax1.plot(df.index, df['출생아 수'], color='#ff812d')

ax2 = ax1.twinx() # x축을 공유하는 쌍둥이 axis
ax2.plot(df.index, df['합계 출산율'], color='#ffd100')

plt.show()

# %%
fig, ax1 = plt.subplots(figsize=(13, 5))
fig.suptitle('출생아 수 및 합계출산율')

ax1.set_ylabel('출생아수(천명)')
ax1.set_ylim(250, 700)
ax1.set_yticks([300, 400, 500, 600])
ax1.bar(df.index, df['출생아 수'], color='#ff812d')
for idx, value in enumerate(df['출생아 수']):
    ax1.text(idx, value+12, value, ha='center')

ax2 = ax1.twinx() # x축을 공유하는 쌍둥이 axis
ax2.set_ylabel('합계출산율(가임여성 1명당 명)')
ax2.set_ylim(0, 1.5)
ax2.set_yticks([0, 1])
ax2.plot(df.index, df['합계 출산율'], color='#ffd100', marker='o', ms=10, mec='w', mew=3, lw=5)
for idx, value in enumerate(df['합계 출산율']):
    ax2.text(idx, value+0.08, value, ha='center')

plt.show()
